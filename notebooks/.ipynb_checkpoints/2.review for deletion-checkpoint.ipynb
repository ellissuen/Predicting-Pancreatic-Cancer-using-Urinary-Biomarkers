# %%
import sys
sys.path.append('../scripts')

# %%
from open_file import open_file

# %%
df = open_file()
df
# Out:
#      age  is_male  plasma_CA19_9  creatinine     LYVE1       REG1B  \
# 0     33        0           11.7     1.83222  0.893219   52.948840
# 1     81        0            NaN     0.97266  2.037585   94.467030
# 2     51        1            7.0     0.78039  0.145589  102.366000
# 3     61        1            8.0     0.70122  0.002805   60.579000
# 4     62        1            9.0     0.21489  0.000860   65.540000
# ..   ...      ...            ...         ...       ...         ...
# 585   68        1            NaN     0.52026  7.058209  156.241000
# 586   71        0            NaN     0.85956  8.341207   16.915000
# 587   63        1            NaN     1.36851  7.674707  289.701000
# 588   75        0            NaN     1.33458  8.206777  205.930000
# 589   74        1         1488.0     1.50423  8.200958  411.938275
#
#             TFF1      REG1A  diagnosis
# 0     654.282174   1262.000          1
# 1     209.488250    228.407          1
# 2     461.141000        NaN          1
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, RobustScaler, QuantileTransformer
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# Step 1: Handle Missing Values
missing_methods = ['remove', 'mean', 'knn']

for missing_method in missing_methods:
    if missing_method == 'remove':
        # Remove columns with missing values
        # df_removed = df.dropna(axis=1)
        pass
    elif missing_method == 'mean':
        # Replace missing values with mean
        # df_mean = df.fillna(df.mean())
        pass
    elif missing_method == 'knn':
        # Impute missing values with KNN
        # df_knn = KNNImputer().fit_transform(df)
        pass

    # Step 2: Scaling/Normalization
    scaling_methods = [MinMaxScaler(), RobustScaler(), QuantileTransformer(), np.log1p]

    for scaling_method in scaling_methods:
        # Apply scaling/normalization
        # scaled_data = scaling_method.fit_transform(df_removed or df_mean or df_knn)
        pass

        # Step 3: Feature Selection
        feature_selection_methods = ['RFE', 'without RFE']

        for feature_selection_method in feature_selection_methods:
            if feature_selection_method == 'RFE':
                # Perform Recursive Feature Elimination
                # selected_features = RFE(estimator, n_features_to_select=5).fit_transform(scaled_data, target)
                pass
            elif feature_selection_method == 'without RFE':
                # Use all features without RFE
                # selected_features = scaled_data
                pass

            # Step 4: Data Split
            split_methods = ['train_test_split', 'repeated cross-validation', 'holdout validation']

            for split_method in split_methods:
                if split_method == 'train_test_split':
                    # Split data into train and test sets
                    # X_train, X_test, y_train, y_test = train_test_split(selected_features, target, test_size=0.2, random_state=42)
                    pass
                elif split_method == 'repeated cross-validation':
                    # Perform repeated cross-validation
                    # scores = cross_val_score(estimator, selected_features, target, cv=10)
                    pass
                elif split_method == 'holdout validation':
                    # Implement holdout validation
                    # ...
                    pass
00
                # Step 5: Model Selection
                models = [LogisticRegression(), RandomForestClassifier(), GradientBoostingClassifier(), SVC(), KNeighborsClassifier()]

                for model in models:
                    # Train the model
                    # model.fit(X_train, y_train)

                    # Evaluate the model
                    # accuracy = model.score(X_test, y_test)
                    # print("Accuracy:", accuracy)
# Out:
#   Cell In[7], line 74
#     # print("Accuracy:", accuracy)
#                                   ^
# SyntaxError: incomplete input

# %% [markdown]
# # Testing

# %%
import pandas as pd

# %%
import sys
sys.path.append('../scripts')

# %%
import data_preprocessing

# %%
missing_value_functions = [data_preprocessing.remove_missing, 
                           data_preprocessing.mean_missing, 
                           data_preprocessing.knn_missing]

for func in missing_value_functions:
    result_df = func()
    print(result_df.describe())  # Check the type of the object

    print()
# Out:
#               age     is_male  creatinine       LYVE1        REG1B  \
# count  590.000000  590.000000  590.000000  590.000000   590.000000
# mean    59.079661    0.493220    0.855383    3.063530   111.774090
# std     13.109520    0.500378    0.639028    3.438796   196.267110
# min     26.000000    0.000000    0.056550    0.000129     0.001104
# 25%     50.000000    0.000000    0.373230    0.167179    10.757216
# 50%     60.000000    0.000000    0.723840    1.649862    34.303353
# 75%     69.000000    1.000000    1.139482    5.205037   122.741013
# max     89.000000    1.000000    4.116840   23.890323  1403.897600
#
#                TFF1   diagnosis
# count    590.000000  590.000000
# mean     597.868722    2.027119
# std     1010.477245    0.804873
# min        0.005293    1.000000
# 25%       43.961000    1.000000
# 50%      259.873974    2.000000
# 75%      742.736000    3.000000
# max    13344.300000    3.000000
#
# ...

# %%
# trial to see 1-3 (12 permutations) of my imputer and scalers using my py scripts


import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler, RobustScaler, QuantileTransformer
import numpy as np

# Define the missing value imputation methods and their descriptions
missing_value_functions = {
    remove_missing: "Remove Missing Values",
    mean_missing: "Replace with Mean",
    knn_missing: "Replace with KNN"
}

# Define the scaling/normalization methods and their descriptions
scaling_normalization_functions = {
    min_max_scaler: "Min-Max Scaling",
    robust_scaler: "Robust Scaling",
    quant_transformation: "Quantile Transformation",
    log_transformation: "Log Transformation"
}

# Iterate over each missing value imputation method
for missing_func, missing_desc in missing_value_functions.items():
    imputed_df = missing_func()
    
    # Iterate over each scaling/normalization method
    for scaling_func, scaling_desc in scaling_normalization_functions.items():
        transformed_data = scaling_func(imputed_df)
        transformed_df = pd.DataFrame(transformed_data, columns=imputed_df.columns)
        
        # Print information about the missing value imputation and scaling/normalization methods used
        print(f"Missing Value Imputation: {missing_desc}")
        print(f"Scaling/Normalization: {scaling_desc}")
        
        # Print the DataFrame
        print("\nDataFrame:")
        print(type(transformed_df))
        print(transformed_df)
        print("\n" + "-"*50 + "\n")  # Add a separator between dataframes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 11
#       7 import numpy as np
#       9 # Define the missing value imputation methods and their descriptions
#      10 missing_value_functions = {
# ---> 11     remove_missing: "Remove Missing Values",
#      12     mean_missing: "Replace with Mean",
#      13     knn_missing: "Replace with KNN"
#      14 }
#      16 # Define the scaling/normalization methods and their descriptions
#      17 scaling_normalization_functions = {
#      18     min_max_scaler: "Min-Max Scaling",
#      19     robust_scaler: "Robust Scaling",
#      20     quant_transformation: "Quantile Transformation",
#      21     log_transformation: "Log Transformation"
#      22 }
#
# NameError: name 'remove_missing' is not defined

# %%
# graph distribution of all step 1-3 in my notes



import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler, RobustScaler, QuantileTransformer
import numpy as np

# Define the missing value imputation methods and their descriptions
missing_value_functions = {
    remove_missing: "Remove Missing Values",
    mean_missing: "Replace with Mean",
    knn_missing: "Replace with KNN"
}

# Define the scaling/normalization methods and their descriptions
scaling_normalization_functions = {
    min_max_scaler: "Min-Max Scaling",
    robust_scaler: "Robust Scaling",
    quant_transformation: "Quantile Transformation",
    log_transformation: "Log Transformation"
}

# Iterate over each missing value imputation method
for missing_func, missing_desc in missing_value_functions.items():
    imputed_df = missing_func()
    
    # Iterate over each scaling/normalization method
    for scaling_func, scaling_desc in scaling_normalization_functions.items():
        transformed_data = scaling_func(imputed_df)
        transformed_df = pd.DataFrame(transformed_data, columns=imputed_df.columns)
        
        # Print information about the missing value imputation and scaling/normalization methods used
        print(f"Missing Value Imputation: {missing_desc}")
        print(f"Scaling/Normalization: {scaling_desc}")
        
        # Plot distribution charts for each column
        for column in transformed_df.columns:
            plt.figure(figsize=(8, 6))
            sns.histplot(transformed_df[column], kde=True)
            plt.title(f"Distribution of {column}")
            plt.xlabel(column)
            plt.ylabel("Frequency")
            plt.show()
        
        print("\n" + "-"*50 + "\n")  # Add a separator between dataframes
# Out:
# Missing Value Imputation: Remove Missing Values
# Scaling/Normalization: Min-Max Scaling
# --------------------------------------------------
#
# Missing Value Imputation: Remove Missing Values
# Scaling/Normalization: Robust Scaling
# --------------------------------------------------
#
# Missing Value Imputation: Remove Missing Values
# Scaling/Normalization: Quantile Transformation
# --------------------------------------------------
#
# Missing Value Imputation: Remove Missing Values
# Scaling/Normalization: Log Transformation
# --------------------------------------------------
#
# Missing Value Imputation: Replace with Mean
# Scaling/Normalization: Min-Max Scaling
# --------------------------------------------------
#
# Missing Value Imputation: Replace with Mean
# Scaling/Normalization: Robust Scaling
# --------------------------------------------------
#
# Missing Value Imputation: Replace with Mean
# Scaling/Normalization: Quantile Transformation
# ...

# %% [markdown]
# # Step 1. Optimal Missing Value Imputation

# %%
import sys
sys.path.append('../scripts')

import data_preprocessing

# %%
#KEEEEP 91.5%

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import RFE
from sklearn.linear_model import Lasso

missing_value_functions = data_preprocessing.missing_value_functions
scaling_normalization_functions = data_preprocessing.scaling_normalization_functions
feature_selection_functions = data_preprocessing.feature_selection_functions

# Define classifier functions
gbm_classifier = data_preprocessing.gbm_classifier
classifier_functions = {
    gbm_classifier: "gbm Classifier"
}

for missing_func, missing_desc in missing_value_functions.items():
    imputed_df = missing_func()
    
    X = imputed_df.iloc[:, :-1]
    y = imputed_df.iloc[:, -1:]
    
    def classify_diagnosis(value):
        if value in [1, 2]:
            return '0'
        else:
            return '1'

    # Apply the classification function to each value in the 'diagnosis' column
    y = y['diagnosis'].apply(classify_diagnosis)
    
    for scaling_func, scaling_desc in scaling_normalization_functions.items():
        X_transformed_data = scaling_func(X)
        X_transformed_df = pd.DataFrame(X_transformed_data, columns=imputed_df.columns[:-1])
        
        # Feature Selection
        estimator = Lasso()
        selector = RFE(estimator, n_features_to_select=6)
        selector = selector.fit(X_transformed_df, y)
        selected_features = X.columns[selector.support_]

        # Subset X with selected features
        X_selected = X[selected_features]
        
        print("Selected Features:")
        for feature in selected_features:
            print(feature)

        # Train-test split
        X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)
        
        for classifier_func, classifier_desc in classifier_functions.items():
            classifier_model = classifier_func(X_train, X_test, y_train, y_test)

            y_pred = classifier_model.predict(X_test)
            accuracy = accuracy_score(y_test, y_pred)

            print(f"Missing Value Imputation: {missing_desc}")
            print(f'Scaling/Normalization: {scaling_desc}')
            print(f'Feature Selection: RFE with Lasso')

            print(f'Classification Model: {classifier_desc}')

            print(f'Accuracy: {accuracy}')
            print("\n" + "-"*50 + "\n")  # Add a separator between dataframes
# Out:
# Selected Features:
# age
# is_male
# creatinine
# LYVE1
# REG1B
# TFF1
# Missing Value Imputation: Remove Missing Values
# Scaling/Normalization: Min-Max Scaling
# Feature Selection: RFE with Lasso
# Classification Model: gbm Classifier
# Accuracy: 0.8220338983050848
#
# --------------------------------------------------
#
# Selected Features:
# age
# is_male
# creatinine
# LYVE1
# REG1B
# TFF1
# Missing Value Imputation: Remove Missing Values
# Scaling/Normalization: Robust Scaling
# Feature Selection: RFE with Lasso
# Classification Model: gbm Classifier
# Accuracy: 0.8220338983050848
#
# --------------------------------------------------
#
# Selected Features:
# age
# is_male
# creatinine
# LYVE1
# REG1B
# TFF1
# Missing Value Imputation: Remove Missing Values
# Scaling/Normalization: Quantile Transformation
# Feature Selection: RFE with Lasso
# Classification Model: gbm Classifier
# Accuracy: 0.8220338983050848
#
# --------------------------------------------------
#
# ...

# %% [markdown]
# # Next

# %% [markdown]
# Mean missing replacement most likely the best
#
# with RFE Lasso feature selection n = 6, 7

# %%
import sys
sys.path.append('../scripts')

import data_preprocessing

# %%
imputed_df = data_preprocessing.mean_missing()

# %%
X = imputed_df.iloc[:, :-1]
y = imputed_df.iloc[:, -1:]

# %%
def classify_diagnosis(value):
        if value in [1, 2]:
            return '0'
        else:
            return '1'
y = y['diagnosis'].apply(classify_diagnosis)

# %%
X_scaled_df = data_preprocessing.robust_scaler(X)

# %%
# Feature Selection
estimator = Lasso()
selector = RFE(estimator, n_features_to_select=6)
selector = selector.fit(X_scaled_df, y)
selected_features = X.columns[selector.support_]

# Subset X with selected features
X_selected = X[selected_features]



# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

print(selected_features)
# Out:
# Index(['plasma_CA19_9', 'creatinine', 'LYVE1', 'REG1B', 'TFF1', 'REG1A'], dtype='object')

# %%
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
# Define hyperparameters for GBM
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', None],
    'subsample': [0.8, 0.9, 1.0],
    'loss': ['deviance', 'exponential']
}

# Initialize GBM classifier
gbm_model = GradientBoostingClassifier()

# Perform Grid Search
grid_search = GridSearchCV(gbm_model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f'Best Parameters: {best_params}')
print(f'Best Score: {best_score}')

# Use the best model from Grid Search
best_gbm_model = grid_search.best_estimator_

# Make predictions on the test data
y_pred = best_gbm_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# C:\Users\ellis\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 14580 fits failed out of a total of 21870.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10935 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ellis\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ellis\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ellis\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
# Define hyperparameters for GBM
param_grid = {
    'n_estimators': [50],
    'learning_rate': [0.2],
    'max_depth': [3],
    'min_samples_split': [5],
    'min_samples_leaf': [2],
    'max_features': ['auto', 'sqrt', None],
    'subsample': [0.8],
    'loss': ['exponential']
}

# Initialize GBM classifier
gbm_model = GradientBoostingClassifier()

# Perform Grid Search
grid_search = GridSearchCV(gbm_model, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f'Best Parameters: {best_params}')
print(f'Best Score: {best_score}')

# Use the best model from Grid Search
best_gbm_model = grid_search.best_estimator_

# Make predictions on the test data
y_pred = best_gbm_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Best Parameters: {'learning_rate': 0.2, 'loss': 'exponential', 'max_depth': 3, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50, 'subsample': 0.8}
# Best Score: 0.86006718924972
# Accuracy: 0.923728813559322
# C:\Users\ellis\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 5 fits failed out of a total of 15.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ellis\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Convert string labels to numerical labels
label_encoder = LabelEncoder()
y_test_numerical = label_encoder.fit_transform(y_test)

# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test_numerical, y_probs)

# Calculate the AUC (Area Under Curve)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
from sklearn.metrics import classification_report

# Assuming y_test contains the true labels and y_pred contains the predicted labels
report = classification_report(y_test, y_pred)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94        80
#            1       0.85      0.92      0.89        38
#
#     accuracy                           0.92       118
#    macro avg       0.91      0.92      0.91       118
# weighted avg       0.93      0.92      0.92       118

# %% [markdown]
# 93.5%
# param_grid = {
#     'n_estimators': [50],
#     'learning_rate': [0.2],
#     'max_depth': [3],
#     'min_samples_split': [5],
#     'min_samples_leaf': [2],
#     'max_features': ['sqrt'],
#     'subsample': [0.8],
#     'loss': ['exponential']
# }
# ????

# %% [markdown]
# Best Parameters: {'learning_rate': 0.2, 'loss': 'exponential', 'max_depth': 2, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 40, 'subsample': 0.8}
# Best Score: 0.8790817469204926
# Accuracy: 0.9067796610169492

# %% [markdown]
# Best Parameters: {'learning_rate': 0.2, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50, 'subsample': 0.8}
# Best Score: 0.8769988801791714
# Accuracy: 0.8559322033898306

# %% [markdown]
# Best Parameters: {'learning_rate': 0.2, 'loss': 'exponential', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 50, 'subsample': 0.8}
# Best Score: 0.8769988801791714
# Accuracy: 0.8559322033898306

# %%
gbm_model = data_preprocessing.gbm_classifier(X_train, X_test, y_train, y_test)

y_pred = gbm_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9152542372881356

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred)

cm_percentage = (cm / total_samples) * 100

print(cm)
# Out:
# [[74  6]
#  [ 3 35]]

# %%
# Confusion matrix
conf_matrix = np.array([[TP, FP],
                        [FN, TN]])  # Assuming TP, TN, FP, FN are defined



# Total samples
total_samples = np.sum(conf_matrix)

# Calculate percentages
pct_actual_positives = np.sum(conf_matrix[1]) / total_samples * 100
pct_actual_negatives = np.sum(conf_matrix[0]) / total_samples * 100

print("Percentage of Actual Positives:", pct_actual_positives)
print("Percentage of Actual Negatives:", pct_actual_negatives)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[176], line 2
#       1 # Confusion matrix
# ----> 2 conf_matrix = np.array([[TP, FP],
#       3                         [FN, TN]])  # Assuming TP, TN, FP, FN are defined
#       5 # Total samples
#       6 total_samples = np.sum(conf_matrix)
#
# NameError: name 'TP' is not defined

# %%
y_test_binary = y_test.astype(int)

# %%
y_pred_numeric = y_pred.astype(float)

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

precision, recall, thresholds = precision_recall_curve(y_test_binary, y_pred_numeric)
avg_precision = average_precision_score(y_test_binary, y_pred_numeric)

# %%
# Plot precision-recall curve
plt.figure()
plt.plot(recall, precision, marker='.')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (AP={:.2f})'.format(avg_precision))
plt.grid(True)
plt.show()

# %%
['plasma_CA19_9', 'creatinine', 'LYVE1', 'REG1B', 'TFF1', 'REG1A']

feature_importance = best_gbm_model.feature_importances_

# Assuming 'features' is a list of feature names
# If you don't have feature names, you can use indices (e.g., range(len(feature_importance)))
features = ['plasma_CA19_9', 'creatinine', 'LYVE1', 'REG1B', 'TFF1', 'REG1A']

feature_importance_combined = list(zip(features, feature_importance))

# Sort features by importance weight
feature_importance_combined.sort(key=lambda x: x[1], reverse=True)

# Unzip sorted features and importance scores
sorted_features, sorted_importance = zip(*feature_importance_combined)

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(sorted_features, sorted_importance, color=(0, 0, 0.5))

# Add labels and title
plt.xticks(rotation=90)
plt.xlabel('Features')
plt.ylabel('Importance Score')
plt.title('Feature Importance')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show plot
plt.tight_layout()
plt.show()

# %%
feature_importance = best_gbm_model.feature_importances_
feature_importance
# Out:
# array([0.29513633, 0.09950226, 0.34855426, 0.10277691, 0.09422613,
#        0.05980411])

# %%
top3_indices = np.argsort(feature_importance)[::-1][:3]
top3_indices
# Out:
# array([2, 0, 3], dtype=int64)

# %%
top3_features = [features[i] for i in top3_indices]
top3_features
# Out:
# ['LYVE1', 'plasma_CA19_9', 'REG1B']

# %%
X_array = X.to_numpy()

# %%
# Step 1: Generate Grid Points
x_min, x_max = X_array[:, top3_indices[0]].min() - 1, X_array[:, top3_indices[0]].max() + 1
y_min, y_max = X_array[:, top3_indices[1]].min() - 1, X_array[:, top3_indices[1]].max() + 1
z_min, z_max = X_array[:, top3_indices[2]].min() - 1, X_array[:, top3_indices[2]].max() + 1
xx, yy, zz = np.meshgrid(np.arange(x_min, x_max, 1),
                         np.arange(y_min, y_max, 1),
                         np.arange(z_min, z_max, 1))

# %%
# Step 2: Predict Class Labels
Z = best_gbm_model.predict(grid_points)
Z = Z.reshape(xx.shape)
# Out:
# C:\Users\ellis\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[148], line 2
#       1 # Step 2: Predict Class Labels
# ----> 2 Z = best_gbm_model.predict(grid_points)
#       3 Z = Z.reshape(xx.shape)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:1286, in GradientBoostingClassifier.predict(self, X)
#    1271 def predict(self, X):
#    1272     """Predict class for X.
#    1273
#    1274     Parameters
#    (...)
#    1284         The predicted values.
#    1285     """
# -> 1286     raw_predictions = self.decision_function(X)
#    1287     encoded_labels = self._loss._raw_prediction_to_decision(raw_predictions)
#    1288     return self.classes_.take(encoded_labels, axis=0)
# ...

# %%
# Step 1: Generate Grid Points
x_min, x_max = X[:, top3_indices[0]].min() - 1, X[:, top3_indices[0]].max() + 1
y_min, y_max = X[:, top3_indices[1]].min() - 1, X[:, top3_indices[1]].max() + 1
z_min, z_max = X[:, top3_indices[2]].min() - 1, X[:, top3_indices[2]].max() + 1
xx, yy, zz = np.meshgrid(np.arange(x_min, x_max, 0.1),
                         np.arange(y_min, y_max, 0.1),
                         np.arange(z_min, z_max, 0.1))

# Step 2: Predict Class Labels
grid_points = np.c_[xx.ravel(), yy.ravel(), zz.ravel()]
Z = best_gbm_model.predict(grid_points)
Z = Z.reshape(xx.shape)

# Step 3: Plot Decision Boundary
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the actual data points
ax.scatter(X[:, top3_indices[0]], X[:, top3_indices[1]], X[:, top3_indices[2]], c=y, cmap=plt.cm.bwr, edgecolors='k', s=40)

# Plot the decision boundaries
ax.contour3D(xx, yy, zz, Z, 50, cmap='coolwarm', alpha=0.5)

# Set labels and title
ax.set_xlabel(top3_features[0])
ax.set_ylabel(top3_features[1])
ax.set_zlabel(top3_features[2])
ax.set_title('Decision Boundary in 3D Space (GBM Model)')

plt.show()
